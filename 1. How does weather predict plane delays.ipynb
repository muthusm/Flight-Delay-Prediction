# %% [markdown]
# #### Reading data from FLIGHTDELAY TABLE AND CREATING SPARK DATAFRAME

# %%
df = sqlContext.table("flightdelay")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 49945499</div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Year: integer (nullable = true)
# -- Quarter: integer (nullable = true)
# -- Month: integer (nullable = true)
# -- DayofMonth: integer (nullable = true)
# -- DayOfWeek: integer (nullable = true)
# -- FlightDate: string (nullable = true)
# -- Reporting_Airline: string (nullable = true)
# -- DOT_ID_Reporting_Airline: integer (nullable = true)
# -- IATA_CODE_Reporting_Airline: string (nullable = true)
# -- Tail_Number: string (nullable = true)
# -- Flight_Number_Reporting_Airline: integer (nullable = true)
# -- OriginAirportID: integer (nullable = true)
# -- OriginAirportSeqID: integer (nullable = true)
# -- OriginCityMarketID: integer (nullable = true)
# -- Origin: string (nullable = true)
# -- OriginCityName: string (nullable = true)
# -- OriginState: string (nullable = true)
# -- OriginStateFips: integer (nullable = true)
# -- OriginStateName: string (nullable = true)
# -- OriginWac: integer (nullable = true)
# -- DestAirportID: integer (nullable = true)
# -- DestAirportSeqID: integer (nullable = true)
# -- DestCityMarketID: integer (nullable = true)
# -- Dest: string (nullable = true)
# -- DestCityName: string (nullable = true)
# -- DestState: string (nullable = true)
# -- DestStateFips: integer (nullable = true)
# -- DestStateName: string (nullable = true)
# -- DestWac: integer (nullable = true)
# -- CRSDepTime: integer (nullable = true)
# -- DepTime: integer (nullable = true)
# -- DepDelay: double (nullable = true)
# -- DepDelayMinutes: string (nullable = true)
# -- DepDel15: double (nullable = true)
# -- DepartureDelayGroups: integer (nullable = true)
# -- DepTimeBlk: string (nullable = true)
# -- TaxiOut: double (nullable = true)
# -- WheelsOff: integer (nullable = true)
# -- WheelsOn: integer (nullable = true)
# -- TaxiIn: double (nullable = true)
# -- CRSArrTime: integer (nullable = true)
# -- ArrTime: integer (nullable = true)
# -- ArrDelay: string (nullable = true)
# -- ArrDelayMinutes: double (nullable = true)
# -- ArrDel15: double (nullable = true)
# -- ArrivalDelayGroups: integer (nullable = true)
# -- ArrTimeBlk: string (nullable = true)
# -- Cancelled: double (nullable = true)
# -- CancellationCode: string (nullable = true)
# -- Diverted: double (nullable = true)
# -- CRSElapsedTime: double (nullable = true)
# -- ActualElapsedTime: double (nullable = true)
# -- AirTime: double (nullable = true)
# -- Flights: double (nullable = true)
# -- Distance: double (nullable = true)
# -- DistanceGroup: integer (nullable = true)
# -- CarrierDelay: double (nullable = true)
# -- WeatherDelay: double (nullable = true)
# -- NASDelay: double (nullable = true)
# -- SecurityDelay: double (nullable = true)
# -- LateAircraftDelay: double (nullable = true)
# -- FirstDepTime: integer (nullable = true)
# -- TotalAddGTime: double (nullable = true)
# -- LongestAddGTime: double (nullable = true)
# -- DivAirportLandings: integer (nullable = true)
# -- DivReachedDest: double (nullable = true)
# -- DivActualElapsedTime: double (nullable = true)
# -- DivArrDelay: double (nullable = true)
# -- DivDistance: double (nullable = true)
# -- Div1Airport: string (nullable = true)
# -- Div1AirportID: integer (nullable = true)
# -- Div1AirportSeqID: integer (nullable = true)
# -- Div1WheelsOn: integer (nullable = true)
# -- Div1TotalGTime: double (nullable = true)
# -- Div1LongestGTime: double (nullable = true)
# -- Div1WheelsOff: integer (nullable = true)
# -- Div1TailNum: string (nullable = true)
# -- Div2Airport: string (nullable = true)
# -- Div2AirportID: integer (nullable = true)
# -- Div2AirportSeqID: integer (nullable = true)
# -- Div2WheelsOn: integer (nullable = true)
# -- Div2TotalGTime: double (nullable = true)
# -- Div2LongestGTime: double (nullable = true)
# -- Div2WheelsOff: integer (nullable = true)
# -- Div2TailNum: string (nullable = true)
# -- Div3Airport: string (nullable = true)
# -- Div3AirportID: integer (nullable = true)
# -- Div3AirportSeqID: integer (nullable = true)
# -- Div3WheelsOn: integer (nullable = true)
# -- Div3TotalGTime: double (nullable = true)
# -- Div3LongestGTime: double (nullable = true)
# -- Div3WheelsOff: integer (nullable = true)
# -- Div3TailNum: string (nullable = true)
# -- Div4Airport: string (nullable = true)
# -- Div4AirportID: string (nullable = true)
# -- Div4AirportSeqID: string (nullable = true)
# -- Div4WheelsOn: string (nullable = true)
# -- Div4TotalGTime: string (nullable = true)
# -- Div4LongestGTime: string (nullable = true)
# -- Div4WheelsOff: string (nullable = true)
# -- Div4TailNum: string (nullable = true)
# -- Div5Airport: string (nullable = true)
# -- Div5AirportID: string (nullable = true)
# -- Div5AirportSeqID: string (nullable = true)
# -- Div5WheelsOn: string (nullable = true)
# -- Div5TotalGTime: string (nullable = true)
# -- Div5LongestGTime: string (nullable = true)
# -- Div5WheelsOff: string (nullable = true)
# -- Div5TailNum: string (nullable = true)
# -- _c109: string (nullable = true)
#
# </div>

# %% [markdown]
# ### NUMBER OF FLIGHTS DELAYED DUE TO WEATHER EACH YEAR FROM 2012 to 2019

# %%
# %sql

SELECT YEAR, COUNT(weatherDelay) AS NUMBER_OF_FLIGHTS
FROM flightdelay
WHERE weatherDelay is not null
AND weatherDelay > 0
AND TAIL_NUMBER is not null
GROUP BY YEAR
ORDER BY YEAR;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YEAR</th><th>NUMBER_OF_FLIGHTS</th></tr></thead><tbody><tr><td>2012</td><td>52525</td></tr><tr><td>2013</td><td>67281</td></tr><tr><td>2014</td><td>71556</td></tr><tr><td>2015</td><td>62096</td></tr><tr><td>2016</td><td>50143</td></tr><tr><td>2017</td><td>49408</td></tr><tr><td>2018</td><td>85055</td></tr><tr><td>2019</td><td>82237</td></tr></tbody></table></div>

# %%
# Monthly Flights
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

SELECT Month, COUNT(weatherDelay) AS NUMBER_OF_FLIGHTS
FROM flightdelay
WHERE weatherDelay is not null
AND weatherDelay > 0
AND TAIL_NUMBER is not null
GROUP BY Month
ORDER BY Month;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Month</th><th>NUMBER_OF_FLIGHTS</th></tr></thead><tbody><tr><td>1</td><td>52832</td></tr><tr><td>2</td><td>41676</td></tr><tr><td>3</td><td>34042</td></tr><tr><td>4</td><td>37427</td></tr><tr><td>5</td><td>46399</td></tr><tr><td>6</td><td>65288</td></tr><tr><td>7</td><td>61765</td></tr><tr><td>8</td><td>52290</td></tr><tr><td>9</td><td>28522</td></tr><tr><td>10</td><td>22105</td></tr><tr><td>11</td><td>29248</td></tr><tr><td>12</td><td>48707</td></tr></tbody></table></div>

# %%
# Weekly Flights
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

SELECT DayOfWeek, COUNT(weatherDelay) AS NUMBER_OF_FLIGHTS
FROM flightdelay
WHERE weatherDelay is not null
AND weatherDelay > 0
AND TAIL_NUMBER is not null
GROUP BY DayOfWeek
ORDER BY DayOfWeek;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DayOfWeek</th><th>NUMBER_OF_FLIGHTS</th></tr></thead><tbody><tr><td>1</td><td>82465</td></tr><tr><td>2</td><td>72370</td></tr><tr><td>3</td><td>74372</td></tr><tr><td>4</td><td>83080</td></tr><tr><td>5</td><td>77387</td></tr><tr><td>6</td><td>58330</td></tr><tr><td>7</td><td>72297</td></tr></tbody></table></div>

# %% [markdown]
# ### AVERAGE DELAY TIME DUE TO WEATHER EACH YEAR FROM 2012 to 2019

# %%
# %sql

SELECT YEAR, AVG(weatherDelay) AS AVERAGE_DELAY_TIME_In_MINUTES
FROM flightdelay
WHERE weatherDelay is not null
AND weatherDelay > 0
AND TAIL_NUMBER is not null
GROUP BY YEAR
ORDER BY YEAR;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YEAR</th><th>AVERAGE_DELAY_TIME_In_MINUTES</th></tr></thead><tbody><tr><td>2012</td><td>43.40428367444074</td></tr><tr><td>2013</td><td>42.139757137973575</td></tr><tr><td>2014</td><td>43.93916652691598</td></tr><tr><td>2015</td><td>48.158883019840246</td></tr><tr><td>2016</td><td>51.973017170891254</td></tr><tr><td>2017</td><td>56.66610670336787</td></tr><tr><td>2018</td><td>57.83404855681618</td></tr><tr><td>2019</td><td>64.23508882862944</td></tr></tbody></table></div>

# %% [markdown]
# ### AVERAGE DELAY TIME DUE TO WEATHER EACH MONTH ACROSS ALL YEARS FROM 2012 to 2019

# %%
# %sql

SELECT MONTH, AVG(weatherDelay) AS AVERAGE_DELAY_TIME_In_MINUTES
FROM flightdelay
WHERE weatherDelay is not null
AND weatherDelay > 0
AND TAIL_NUMBER is not null
GROUP BY MONTH
ORDER BY MONTH;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MONTH</th><th>AVERAGE_DELAY_TIME_In_MINUTES</th></tr></thead><tbody><tr><td>1</td><td>52.075806329497276</td></tr><tr><td>2</td><td>52.142000191957</td></tr><tr><td>3</td><td>49.743610833676044</td></tr><tr><td>4</td><td>52.94845966815401</td></tr><tr><td>5</td><td>54.65219077997371</td></tr><tr><td>6</td><td>50.565555691704446</td></tr><tr><td>7</td><td>53.00917995628592</td></tr><tr><td>8</td><td>50.59607955632052</td></tr><tr><td>9</td><td>50.44001121940958</td></tr><tr><td>10</td><td>49.86532458719746</td></tr><tr><td>11</td><td>50.40187363238512</td></tr><tr><td>12</td><td>51.032007719629625</td></tr></tbody></table></div>

# %% [markdown]
# ### AVERAGE DELAY TIME DUE TO WEATHER EACH DAY OF WEEK

# %%
# %sql

SELECT DAYOFWEEK, AVG(weatherDelay) AS AVERAGE_DELAY_TIME_In_MINUTES
FROM flightdelay
WHERE weatherDelay is not null
AND weatherDelay > 0
AND TAIL_NUMBER is not null
GROUP BY DAYOFWEEK
ORDER BY DAYOFWEEK;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DAYOFWEEK</th><th>AVERAGE_DELAY_TIME_In_MINUTES</th></tr></thead><tbody><tr><td>1</td><td>50.44120535984963</td></tr><tr><td>2</td><td>51.612795357192205</td></tr><tr><td>3</td><td>52.489525627924486</td></tr><tr><td>4</td><td>51.5269017814155</td></tr><tr><td>5</td><td>52.13652163800121</td></tr><tr><td>6</td><td>52.750985770615465</td></tr><tr><td>7</td><td>50.706198044178876</td></tr></tbody></table></div>

# %% [markdown]
# #### AVERAGE NUMBER OF FLIGHT DELAYS IN DEPARTURE FOR EACH STATE FOR THE TIME PERIOD 2012 - 2019

# %%
# %sql

SELECT ORIGINSTATE, AVG(NUM_FLIGHTS_DELAYED) AS AVG_NUM_FLIGHTS_DELAYED 
FROM (SELECT YEAR, ORIGINSTATE, COUNT(DepDelay) AS NUM_FLIGHTS_DELAYED 
FROM FLIGHTDELAY 
WHERE DepDelay > 0
GROUP BY YEAR, ORIGINSTATE) AS T1
GROUP BY ORIGINSTATE
ORDER BY ORIGINSTATE
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORIGINSTATE</th><th>AVG_NUM_FLIGHTS_DELAYED</th></tr></thead><tbody><tr><td>AK</td><td>8697.0</td></tr><tr><td>AL</td><td>9431.875</td></tr><tr><td>AR</td><td>7655.125</td></tr><tr><td>AZ</td><td>70881.75</td></tr><tr><td>CA</td><td>290930.0</td></tr><tr><td>CO</td><td>106844.875</td></tr><tr><td>CT</td><td>7228.375</td></tr><tr><td>DE</td><td>152.66666666666666</td></tr><tr><td>FL</td><td>171462.875</td></tr><tr><td>GA</td><td>143709.75</td></tr><tr><td>HI</td><td>27771.875</td></tr><tr><td>IA</td><td>6216.125</td></tr><tr><td>ID</td><td>4961.125</td></tr><tr><td>IL</td><td>171051.75</td></tr><tr><td>IN</td><td>14330.25</td></tr><tr><td>KS</td><td>3429.625</td></tr><tr><td>KY</td><td>15983.75</td></tr><tr><td>LA</td><td>24320.375</td></tr><tr><td>MA</td><td>44002.5</td></tr><tr><td>MD</td><td>44593.625</td></tr><tr><td>ME</td><td>2584.25</td></tr><tr><td>MI</td><td>47445.75</td></tr><tr><td>MN</td><td>39350.625</td></tr><tr><td>MO</td><td>44124.625</td></tr><tr><td>MS</td><td>3774.625</td></tr><tr><td>MT</td><td>3629.375</td></tr><tr><td>NC</td><td>75535.5</td></tr><tr><td>ND</td><td>3776.375</td></tr><tr><td>NE</td><td>7078.75</td></tr><tr><td>NH</td><td>2366.25</td></tr><tr><td>NJ</td><td>50910.25</td></tr><tr><td>NM</td><td>9742.375</td></tr><tr><td>NV</td><td>69693.0</td></tr><tr><td>NY</td><td>97742.625</td></tr><tr><td>OH</td><td>27722.375</td></tr><tr><td>OK</td><td>11661.0</td></tr><tr><td>OR</td><td>20719.125</td></tr><tr><td>PA</td><td>42092.75</td></tr><tr><td>PR</td><td>10148.0</td></tr><tr><td>RI</td><td>4505.25</td></tr><tr><td>SC</td><td>11442.75</td></tr><tr><td>SD</td><td>3003.5</td></tr><tr><td>TN</td><td>34749.5</td></tr><tr><td>TT</td><td>272.875</td></tr><tr><td>TX</td><td>277957.0</td></tr><tr><td>UT</td><td>31423.875</td></tr><tr><td>VA</td><td>60247.875</td></tr><tr><td>VI</td><td>1445.25</td></tr><tr><td>VT</td><td>1644.875</td></tr><tr><td>WA</td><td>46539.875</td></tr><tr><td>WI</td><td>16277.5</td></tr><tr><td>WV</td><td>1309.0</td></tr><tr><td>WY</td><td>2149.75</td></tr></tbody></table></div>

# %%
import plotly.express as px
test_df = sqlContext.sql("SELECT ORIGINSTATE, AVG(NUM_FLIGHTS_DELAYED) AS AVG_NUM_FLIGHTS_DELAYED FROM (SELECT YEAR, ORIGINSTATE, COUNT(DepDelay) AS NUM_FLIGHTS_DELAYED FROM FLIGHTDELAY WHERE DepDelay > 0 GROUP BY YEAR, ORIGINSTATE) AS T1 GROUP BY ORIGINSTATE");
fig = px.choropleth(test_df.toPandas(),locations='ORIGINSTATE',locationmode="USA-states",scope="usa",color='AVG_NUM_FLIGHTS_DELAYED',color_continuous_scale="Viridis_r")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b03f4ecb-e777-44ce-ace6-7f3ecda87289" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b03f4ecb-e777-44ce-ace6-7f3ecda87289")) {                    Plotly.newPlot(                        "b03f4ecb-e777-44ce-ace6-7f3ecda87289",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"ORIGINSTATE=%{location}<br>AVG_NUM_FLIGHTS_DELAYED=%{z}<extra></extra>","locationmode":"USA-states","locations":["AZ","SC","LA","MN","NJ","OR","VA","RI","WY","KY","NH","MI","NV","WI","ID","CA","CT","NE","MT","NC","VT","MD","DE","MO","VI","IL","ME","WA","ND","MS","AL","IN","OH","TN","IA","NM","PA","SD","NY","TX","WV","GA","MA","KS","TT","CO","FL","AK","AR","OK","PR","UT","HI"],"name":"","z":[70881.75,11442.75,24320.375,39350.625,50910.25,20719.125,60247.875,4505.25,2149.75,15983.75,2366.25,47445.75,69693.0,16277.5,4961.125,290930.0,7228.375,7078.75,3629.375,75535.5,1644.875,44593.625,152.66666666666666,44124.625,1445.25,171051.75,2584.25,46539.875,3776.375,3774.625,9431.875,14330.25,27722.375,34749.5,6216.125,9742.375,42092.75,3003.5,97742.625,277957.0,1309.0,143709.75,44002.5,3429.625,272.875,106844.875,171462.875,8697.0,7655.125,11661.0,10148.0,31423.875,27771.875],"type":"choropleth"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"] ...

# %% [markdown]
# #### AVERAGE NUMBER OF FLIGHT DELAYS IN DEPARTURE DUE TO WEATHER FOR EACH STATE FOR THE TIME PERIOD 2012 - 2019

# %%
# %sql

SELECT ORIGINSTATE, AVG(NUM_FLIGHTS_DELAYED) AS AVG_NUM_FLIGHTS_DELAYED 
FROM (SELECT YEAR, ORIGINSTATE, COUNT(*) AS NUM_FLIGHTS_DELAYED 
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY YEAR, ORIGINSTATE) AS T1
GROUP BY ORIGINSTATE
ORDER BY ORIGINSTATE
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORIGINSTATE</th><th>AVG_NUM_FLIGHTS_DELAYED</th></tr></thead><tbody><tr><td>AK</td><td>260.0</td></tr><tr><td>AL</td><td>286.125</td></tr><tr><td>AR</td><td>328.125</td></tr><tr><td>AZ</td><td>559.125</td></tr><tr><td>CA</td><td>2809.375</td></tr><tr><td>CO</td><td>2912.25</td></tr><tr><td>CT</td><td>192.25</td></tr><tr><td>DE</td><td>6.0</td></tr><tr><td>FL</td><td>6363.375</td></tr><tr><td>GA</td><td>5514.25</td></tr><tr><td>HI</td><td>405.375</td></tr><tr><td>IA</td><td>320.875</td></tr><tr><td>ID</td><td>114.625</td></tr><tr><td>IL</td><td>9395.375</td></tr><tr><td>IN</td><td>458.125</td></tr><tr><td>KS</td><td>128.0</td></tr><tr><td>KY</td><td>546.5</td></tr><tr><td>LA</td><td>799.875</td></tr><tr><td>MA</td><td>1295.0</td></tr><tr><td>MD</td><td>799.5</td></tr><tr><td>ME</td><td>64.5</td></tr><tr><td>MI</td><td>1652.5</td></tr><tr><td>MN</td><td>1312.25</td></tr><tr><td>MO</td><td>1045.875</td></tr><tr><td>MS</td><td>141.875</td></tr><tr><td>MT</td><td>109.75</td></tr><tr><td>NC</td><td>2544.5</td></tr><tr><td>ND</td><td>191.125</td></tr><tr><td>NE</td><td>188.125</td></tr><tr><td>NH</td><td>46.75</td></tr><tr><td>NJ</td><td>1326.625</td></tr><tr><td>NM</td><td>190.0</td></tr><tr><td>NV</td><td>763.75</td></tr><tr><td>NY</td><td>3436.375</td></tr><tr><td>OH</td><td>695.375</td></tr><tr><td>OK</td><td>344.0</td></tr><tr><td>OR</td><td>282.625</td></tr><tr><td>PA</td><td>1138.375</td></tr><tr><td>PR</td><td>63.875</td></tr><tr><td>RI</td><td>91.625</td></tr><tr><td>SC</td><td>238.625</td></tr><tr><td>SD</td><td>153.75</td></tr><tr><td>TN</td><td>855.375</td></tr><tr><td>TT</td><td>5.857142857142857</td></tr><tr><td>TX</td><td>10242.5</td></tr><tr><td>UT</td><td>746.625</td></tr><tr><td>VA</td><td>2072.125</td></tr><tr><td>VI</td><td>36.0</td></tr><tr><td>VT</td><td>51.5</td></tr><tr><td>WA</td><td>788.5</td></tr><tr><td>WI</td><td>572.125</td></tr><tr><td>WV</td><td>51.375</td></tr><tr><td>WY</td><td>103.75</td></tr></tbody></table></div>

# %%
import plotly.express as px
test_df = sqlContext.sql("SELECT ORIGINSTATE, AVG(NUM_FLIGHTS_DELAYED) AS AVG_NUM_FLIGHTS_DELAYED FROM (SELECT YEAR, ORIGINSTATE, COUNT(*) AS NUM_FLIGHTS_DELAYED FROM FLIGHTDELAY WHERE weatherDelay > 0 GROUP BY YEAR, ORIGINSTATE) AS T1 GROUP BY ORIGINSTATE");
fig = px.choropleth(test_df.toPandas(),
                    locations='ORIGINSTATE',
                    locationmode="USA-states",
                    scope="usa",
                    color='AVG_NUM_FLIGHTS_DELAYED',
                    color_continuous_scale=[
                        (0.0, "#e5e5e5"),   (0.001449275362, "#e5e5e5"), 
                        (0.01449275362, "#ffe5f0"),   (0.1086956522, "#ffe5f0"), 
                        (0.1086956522, "#facfdf"), (0.1449275362, "#facfdf"), 
                        (0.1449275362, "#f3b8ce"),  (0.3623188406, "#f3b8ce"), 
                        (0.3623188406, "#eca2bf"), (0.7246376812, "#eca2bf"), 
                        (0.7246376812, "#e37fb1"), (1, "#e37fb1") 
                    ])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="556b111c-68a7-4d87-bb85-67a4964171d7" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("556b111c-68a7-4d87-bb85-67a4964171d7")) {                    Plotly.newPlot(                        "556b111c-68a7-4d87-bb85-67a4964171d7",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"ORIGINSTATE=%{location}<br>AVG_NUM_FLIGHTS_DELAYED=%{z}<extra></extra>","locationmode":"USA-states","locations":["AZ","SC","LA","MN","NJ","OR","VA","RI","WY","KY","NH","MI","NV","WI","ID","CA","CT","NE","MT","NC","VT","MD","DE","MO","VI","IL","ME","WA","ND","MS","AL","IN","OH","TN","IA","NM","PA","SD","NY","TX","WV","GA","MA","KS","TT","CO","FL","AK","AR","OK","PR","UT","HI"],"name":"","z":[559.125,238.625,799.875,1312.25,1326.625,282.625,2072.125,91.625,103.75,546.5,46.75,1652.5,763.75,572.125,114.625,2809.375,192.25,188.125,109.75,2544.5,51.5,799.5,6.0,1045.875,36.0,9395.375,64.5,788.5,191.125,141.875,286.125,458.125,695.375,855.375,320.875,190.0,1138.375,153.75,3436.375,10242.5,51.375,5514.25,1295.0,128.0,5.857142857142857,2912.25,6363.375,260.0,328.125,344.0,63.875,746.625,405.375],"type":"choropleth"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333 ...

# %%
# %sql

SELECT ORIGINSTATE, AVG(NUM_FLIGHTS_DELAYED) AS AVG_NUM_FLIGHTS_DELAYED 
FROM (SELECT YEAR, ORIGINSTATE, COUNT(*) AS NUM_FLIGHTS_DELAYED 
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY YEAR, ORIGINSTATE) AS T1
GROUP BY ORIGINSTATE
ORDER BY AVG_NUM_FLIGHTS_DELAYED DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORIGINSTATE</th><th>AVG_NUM_FLIGHTS_DELAYED</th></tr></thead><tbody><tr><td>TX</td><td>10242.5</td></tr><tr><td>IL</td><td>9395.375</td></tr><tr><td>FL</td><td>6363.375</td></tr><tr><td>GA</td><td>5514.25</td></tr><tr><td>NY</td><td>3436.375</td></tr><tr><td>CO</td><td>2912.25</td></tr><tr><td>CA</td><td>2809.375</td></tr><tr><td>NC</td><td>2544.5</td></tr><tr><td>VA</td><td>2072.125</td></tr><tr><td>MI</td><td>1652.5</td></tr></tbody></table></div>

# %%
# %sql

SELECT IATA_CODE_Reporting_Airline, AVG(NUM_FLIGHTS_DELAYED) AS AVG_Number_Delayed 
FROM (SELECT YEAR, IATA_CODE_Reporting_Airline, COUNT(*) AS NUM_FLIGHTS_DELAYED 
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY YEAR, IATA_CODE_Reporting_Airline) AS T1
GROUP BY IATA_CODE_Reporting_Airline
ORDER BY AVG_Number_Delayed DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IATA_CODE_Reporting_Airline</th><th>AVG_Number_Delayed</th></tr></thead><tbody><tr><td>MQ</td><td>10675.5</td></tr><tr><td>AA</td><td>10669.375</td></tr><tr><td>DL</td><td>9621.625</td></tr><tr><td>WN</td><td>8541.875</td></tr><tr><td>UA</td><td>6729.75</td></tr><tr><td>OO</td><td>5797.25</td></tr><tr><td>OH</td><td>5310.0</td></tr><tr><td>YX</td><td>3421.0</td></tr><tr><td>EV</td><td>3218.25</td></tr><tr><td>9E</td><td>2720.3333333333335</td></tr></tbody></table></div>

# %%
# %sql

SELECT IATA_CODE_Reporting_Airline, AVG(ArrDelayMinutes)/8 AS AVG_Delayed 
FROM (SELECT YEAR, ArrDelayMinutes, IATA_CODE_Reporting_Airline, COUNT(*) AS NUM_FLIGHTS_DELAYED 
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY YEAR, ArrDelayMinutes, IATA_CODE_Reporting_Airline) AS T1
GROUP BY IATA_CODE_Reporting_Airline
ORDER BY AVG_Delayed DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IATA_CODE_Reporting_Airline</th><th>AVG_Delayed</th></tr></thead><tbody><tr><td>OO</td><td>45.77235186156266</td></tr><tr><td>DL</td><td>42.56454093705632</td></tr><tr><td>9E</td><td>38.79352226720648</td></tr><tr><td>UA</td><td>36.124892826521865</td></tr><tr><td>AA</td><td>35.899268050028425</td></tr><tr><td>YX</td><td>34.27450980392157</td></tr><tr><td>MQ</td><td>34.07468114786768</td></tr><tr><td>YV</td><td>31.222751215559157</td></tr><tr><td>EV</td><td>28.55715192168238</td></tr><tr><td>OH</td><td>26.73546511627907</td></tr></tbody></table></div>

# %%
# %sql

SELECT IATA_CODE_Reporting_Airline, AVG(ArrDelayMinutes)/8 AS AVG_Delayed 
FROM (SELECT YEAR, ArrDelayMinutes, IATA_CODE_Reporting_Airline, COUNT(*) AS NUM_FLIGHTS_DELAYED 
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
AND IATA_CODE_Reporting_Airline not in ("FL","HA")
GROUP BY YEAR, ArrDelayMinutes, IATA_CODE_Reporting_Airline) AS T1
GROUP BY IATA_CODE_Reporting_Airline
ORDER BY AVG_Delayed ASC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IATA_CODE_Reporting_Airline</th><th>AVG_Delayed</th></tr></thead><tbody><tr><td>VX</td><td>16.726471727343146</td></tr><tr><td>F9</td><td>17.309152542372882</td></tr><tr><td>AS</td><td>17.356530548628427</td></tr><tr><td>US</td><td>21.02975663716814</td></tr><tr><td>NK</td><td>22.259151414309486</td></tr><tr><td>G4</td><td>24.463809946714033</td></tr><tr><td>WN</td><td>25.511101549053357</td></tr><tr><td>B6</td><td>25.619305657604702</td></tr><tr><td>OH</td><td>26.73546511627907</td></tr><tr><td>EV</td><td>28.55715192168238</td></tr></tbody></table></div>

# %%
# %sql

SELECT IATA_CODE_Reporting_Airline, AVG(NUM_FLIGHTS_DELAYED) AS AVG_Number_Delayed 
FROM (SELECT YEAR, IATA_CODE_Reporting_Airline, COUNT(*) AS NUM_FLIGHTS_DELAYED 
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY YEAR, IATA_CODE_Reporting_Airline) AS T1
GROUP BY IATA_CODE_Reporting_Airline
ORDER BY AVG_Number_Delayed ASC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IATA_CODE_Reporting_Airline</th><th>AVG_Number_Delayed</th></tr></thead><tbody><tr><td>HA</td><td>417.625</td></tr><tr><td>FL</td><td>514.0</td></tr><tr><td>F9</td><td>586.875</td></tr><tr><td>AS</td><td>912.375</td></tr><tr><td>NK</td><td>1149.0</td></tr><tr><td>VX</td><td>1763.0</td></tr><tr><td>G4</td><td>1896.0</td></tr><tr><td>B6</td><td>1981.25</td></tr><tr><td>YV</td><td>2253.5</td></tr><tr><td>US</td><td>2595.25</td></tr></tbody></table></div>

# %%
# %sql

SELECT ORIGINSTATE, AVG(NUM_FLIGHTS_DELAYED) AS AVG_Number_Delayed 
FROM (SELECT YEAR, ORIGINSTATE, COUNT(*) AS NUM_FLIGHTS_DELAYED 
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY YEAR, ORIGINSTATE) AS T1
GROUP BY ORIGINSTATE
ORDER BY AVG_Number_Delayed DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORIGINSTATE</th><th>AVG_Number_Delayed</th></tr></thead><tbody><tr><td>TX</td><td>10242.5</td></tr><tr><td>IL</td><td>9395.375</td></tr><tr><td>FL</td><td>6363.375</td></tr><tr><td>GA</td><td>5514.25</td></tr><tr><td>NY</td><td>3436.375</td></tr><tr><td>CO</td><td>2912.25</td></tr><tr><td>CA</td><td>2809.375</td></tr><tr><td>NC</td><td>2544.5</td></tr><tr><td>VA</td><td>2072.125</td></tr><tr><td>MI</td><td>1652.5</td></tr></tbody></table></div>

# %%
# %sql

SELECT ORIGIN, AVG(NUM_FLIGHTS_DELAYED) AS AVG_Number_Delayed 
FROM (SELECT YEAR, ORIGIN, COUNT(*) AS NUM_FLIGHTS_DELAYED 
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY YEAR, ORIGIN) AS T1
GROUP BY ORIGIN
ORDER BY AVG_Number_Delayed DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORIGIN</th><th>AVG_Number_Delayed</th></tr></thead><tbody><tr><td>ORD</td><td>8172.0</td></tr><tr><td>DFW</td><td>5867.375</td></tr><tr><td>ATL</td><td>5342.75</td></tr><tr><td>DEN</td><td>2558.25</td></tr><tr><td>MCO</td><td>2033.75</td></tr><tr><td>IAH</td><td>2024.375</td></tr><tr><td>CLT</td><td>1966.625</td></tr><tr><td>MIA</td><td>1468.75</td></tr><tr><td>JFK</td><td>1445.125</td></tr><tr><td>LGA</td><td>1439.5</td></tr></tbody></table></div>

# %%
# %sql

SELECT ORIGIN, AVG(NUM_FLIGHTS_DELAYED) AS AVG_Number_Delayed 
FROM (SELECT YEAR, ORIGIN, COUNT(*) AS NUM_FLIGHTS_DELAYED 
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY YEAR, ORIGIN) AS T1
GROUP BY ORIGIN
ORDER BY AVG_Number_Delayed asc
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORIGIN</th><th>AVG_Number_Delayed</th></tr></thead><tbody><tr><td>LBF</td><td>1.0</td></tr><tr><td>PSE</td><td>1.0</td></tr><tr><td>GST</td><td>1.0</td></tr><tr><td>SPN</td><td>1.0</td></tr><tr><td>HYA</td><td>1.0</td></tr><tr><td>DLG</td><td>1.3333333333333333</td></tr><tr><td>IPL</td><td>1.5</td></tr><tr><td>RDD</td><td>1.75</td></tr><tr><td>MMH</td><td>2.0</td></tr><tr><td>ADK</td><td>2.0</td></tr></tbody></table></div>

# %%
# %sql
SELECT ORIGIN, AVG(ArrDelay)/360 AS AVG_Arr_Delay 
FROM (SELECT YEAR, ORIGIN, COUNT(*) AS ArrDelay
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY YEAR, ORIGIN) AS T1
GROUP BY ORIGIN
ORDER BY AVG_Arr_Delay DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORIGIN</th><th>AVG_Arr_Delay</th></tr></thead><tbody><tr><td>ORD</td><td>22.7</td></tr><tr><td>DFW</td><td>16.29826388888889</td></tr><tr><td>ATL</td><td>14.840972222222222</td></tr><tr><td>DEN</td><td>7.10625</td></tr><tr><td>MCO</td><td>5.649305555555555</td></tr><tr><td>IAH</td><td>5.623263888888889</td></tr><tr><td>CLT</td><td>5.462847222222222</td></tr><tr><td>MIA</td><td>4.079861111111111</td></tr><tr><td>JFK</td><td>4.014236111111111</td></tr><tr><td>LGA</td><td>3.998611111111111</td></tr></tbody></table></div>

# %%
# %sql

SELECT DEST, AVG(ArrDelay)/360 AS AVG_Arr_Delay 
FROM (SELECT YEAR, DEST, COUNT(*) AS ArrDelay
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY YEAR, DEST) AS T1
GROUP BY DEST
ORDER BY AVG_Arr_Delay DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DEST</th><th>AVG_Arr_Delay</th></tr></thead><tbody><tr><td>DFW</td><td>9.942361111111111</td></tr><tr><td>ORD</td><td>9.555555555555555</td></tr><tr><td>ATL</td><td>9.094097222222222</td></tr><tr><td>LAX</td><td>6.007986111111111</td></tr><tr><td>DEN</td><td>5.626736111111111</td></tr><tr><td>SFO</td><td>5.585416666666666</td></tr><tr><td>IAH</td><td>4.976041666666666</td></tr><tr><td>LGA</td><td>4.763888888888889</td></tr><tr><td>CLT</td><td>4.025</td></tr><tr><td>EWR</td><td>3.9590277777777776</td></tr></tbody></table></div>

# %%
# %sql

SELECT DEST, ORIGIN, COUNT(*) AS TOTAL_COUNT 
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY DEST, ORIGIN 
ORDER BY TOTAL_COUNT DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DEST</th><th>ORIGIN</th><th>TOTAL_COUNT</th></tr></thead><tbody><tr><td>LGA</td><td>ORD</td><td>2534</td></tr><tr><td>DFW</td><td>ORD</td><td>1979</td></tr><tr><td>ATL</td><td>ORD</td><td>1864</td></tr><tr><td>LAX</td><td>ORD</td><td>1859</td></tr><tr><td>MSP</td><td>ORD</td><td>1759</td></tr><tr><td>ORD</td><td>LGA</td><td>1702</td></tr><tr><td>LAX</td><td>JFK</td><td>1653</td></tr><tr><td>SFO</td><td>ORD</td><td>1611</td></tr><tr><td>DCA</td><td>ORD</td><td>1419</td></tr><tr><td>DTW</td><td>ORD</td><td>1396</td></tr></tbody></table></div>

# %%
# %sql

SELECT DEST, ORIGIN, COUNT(*) AS TOTAL_COUNT 
FROM FLIGHTDELAY 
WHERE weatherDelay > 0
GROUP BY DEST, ORIGIN 
ORDER BY TOTAL_COUNT DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DEST</th><th>ORIGIN</th><th>TOTAL_COUNT</th></tr></thead><tbody><tr><td>LGA</td><td>ORD</td><td>2534</td></tr><tr><td>DFW</td><td>ORD</td><td>1979</td></tr><tr><td>ATL</td><td>ORD</td><td>1864</td></tr><tr><td>LAX</td><td>ORD</td><td>1859</td></tr><tr><td>MSP</td><td>ORD</td><td>1759</td></tr><tr><td>ORD</td><td>LGA</td><td>1702</td></tr><tr><td>LAX</td><td>JFK</td><td>1653</td></tr><tr><td>SFO</td><td>ORD</td><td>1611</td></tr><tr><td>DCA</td><td>ORD</td><td>1419</td></tr><tr><td>DTW</td><td>ORD</td><td>1396</td></tr></tbody></table></div>

# %% [markdown]
# #### Seeing Arrival Delay of the flights which had delay in departure due to weather

# %%
# %sql 

SELECT  WEATHERDELAY, AVG(ArrDelay) AS AVG_ARR_DELAY
FROM FLIGHTDELAY
WHERE WEATHERDELAY > 0
AND ArrDelay > 0
GROUP BY WEATHERDELAY
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>WEATHERDELAY</th><th>AVG_ARR_DELAY</th></tr></thead><tbody><tr><td>305.0</td><td>338.37704918032784</td></tr><tr><td>596.0</td><td>658.4444444444445</td></tr><tr><td>692.0</td><td>708.1111111111111</td></tr><tr><td>934.0</td><td>934.0</td></tr><tr><td>299.0</td><td>339.1774193548387</td></tr><tr><td>496.0</td><td>536.3333333333334</td></tr><tr><td>147.0</td><td>176.53863134657837</td></tr><tr><td>184.0</td><td>210.10344827586206</td></tr><tr><td>170.0</td><td>206.62264150943398</td></tr><tr><td>810.0</td><td>813.7777777777778</td></tr><tr><td>720.0</td><td>748.0</td></tr><tr><td>782.0</td><td>807.1666666666666</td></tr><tr><td>160.0</td><td>187.30632911392405</td></tr><tr><td>169.0</td><td>194.97029702970298</td></tr><tr><td>735.0</td><td>778.6666666666666</td></tr><tr><td>608.0</td><td>658.8333333333334</td></tr><tr><td>8.0</td><td>62.45806555269923</td></tr><tr><td>70.0</td><td>101.02922636103152</td></tr><tr><td>67.0</td><td>99.57022943480693</td></tr><tr><td>311.0</td><td>328.84615384615387</td></tr><tr><td>571.0</td><td>648.1666666666666</td></tr><tr><td>486.0</td><td>530.75</td></tr><tr><td>379.0</td><td>405.85714285714283</td></tr><tr><td>168.0</td><td>193.66366366366367</td></tr><tr><td>69.0</td><td>101.73954802259887</td></tr><tr><td>524.0</td><td>574.2222222222222</td></tr><tr><td>206.0</td><td>232.42995169082127</td></tr><tr><td>650.0</td><td>694.1428571428571</td></tr><tr><td>857.0</td><td>906.5</td></tr><tr><td>1164.0</td><td>1236.0</td></tr><tr><td>390.0</td><td>414.7894736842105</td></tr><tr><td>729.0</td><td>745.1428571428571</td></tr><tr><td>840.0</td><td>855.3636363636364</td></tr><tr><td>7.0</td><td>62.008228571428575</td></tr><tr><td>249.0</td><td>272.9834710743802</td></tr><tr><td>925.0</td><td>930.0</td></tr><tr><td>365.0</td><td>389.0</td></tr><tr><td>677.0</td><td>687.5</td></tr><tr><td>401.0</td><td>411.72222222222223</td></tr><tr><td>142.0</td><td>172.01312910284463</td></tr><tr><td>984.0</td><td>987.4</td></tr><tr><td>902.0</td><td>932.875</td></tr><tr><td>1438.0</td><td>1477.0</td></tr><tr><td>191.0</td><td>227.7642276422764</td></tr><tr><td>724.0</td><td>734.0</td></tr><tr><td>611.0</td><td>626.0</td></tr><tr><td>802.0</td><td>827.375</td></tr><tr><td>663.0</td><td>726.0</td></tr><tr><td>329.0</td><td>351.5</td></tr><tr><td>1084.0</td><td>1088.6666666666667</td></tr><tr><td>112.0</td><td>140.32618025751074</td></tr><tr><td>154.0</td><td>179.2107969151671</td></tr><tr><td>921.0</td><td>977.5</td></tr><tr><td>827.0</td><td>837.5</td></tr><tr><td>1047.0</td><td>1050.1666666666667</td></tr><tr><td>936.0</td><td>955.3333333333334</td></tr><tr><td>232.0</td><td>269.46853146853147</td></tr><tr><td>708.0</td><td>723.3333333333334</td></tr><tr><td>521.0</td><td>567.5</td></tr><tr><td>879.0</td><td>879.6666666666666</td></tr><tr><td>124.0</td><td>153.0595041322314</td></tr><tr><td>438.0</td><td>478.5833333333333</td></tr><tr><td>858.0</td><td>929.5</td></tr><tr><td>567.0</td><td>586.0833333333334</td></tr><tr><td>348.0</td><td>362.84375</td></tr><tr><td>303.0</td><td>333.5593220338983</td></tr><tr><td>456.0</td><td>465.8125</td></tr><tr><td>997.0</td><td>1002.5</td></tr><tr><td>410.0</td><td>436.4117647058824</td></tr><tr><td>625.0</td><td>661.8</td></tr><tr><td>685.0</td><td>734.8571428571429</td></tr><tr><td>1161.0</td><td>1164.3333333333333</td></tr><tr><td>588.0</td><td>616.5833333333334</td></tr><tr><td>253.0</td><td>270.7083333333333</td></tr><tr><td>317.0</td><td>339.8478260869565</td></tr><tr><td>775.0</td><td>786.3333333333334</td></tr><tr><td>331.0</td><td>352.1304347826087</td></tr><tr><td>201.0</td><td>227.25688073394497</td></tr><tr><td>128.0</td><td>154.22680412371133</td></tr><tr><td>235.0</td><td>259.9512195121951</td></tr><tr><td>353.0</td><td>385.80645161290323</td></tr><tr><td>800.0</td><td>815.1666666666666</td></tr><tr><td>108.0</td><td>136.4471153846154</td></tr><tr><td ...

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Selecting columns which can be helpful in predicting the arrival delay time of the flights which had delay in departure due to weather

# %%
from pyspark.sql.functions import corr
for col in df.columns:
    print(col, df.select(corr(col, 'ArrDelayMinutes')).collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Year [Row(corr(Year, ArrDelayMinutes)=0.018582254979860168)]
# Quarter [Row(corr(Quarter, ArrDelayMinutes)=-0.010598661161655325)]
# Month [Row(corr(Month, ArrDelayMinutes)=-0.009506260166349506)]
# DayofMonth [Row(corr(DayofMonth, ArrDelayMinutes)=-0.0012372700464188876)]
# DayOfWeek [Row(corr(DayOfWeek, ArrDelayMinutes)=-0.005148471087896586)]
# FlightDate [Row(corr(FlightDate, ArrDelayMinutes)=None)]
# Reporting_Airline [Row(corr(Reporting_Airline, ArrDelayMinutes)=None)]
# DOT_ID_Reporting_Airline [Row(corr(DOT_ID_Reporting_Airline, ArrDelayMinutes)=0.0386296108005764)]
# IATA_CODE_Reporting_Airline [Row(corr(IATA_CODE_Reporting_Airline, ArrDelayMinutes)=None)]
# Tail_Number [Row(corr(Tail_Number, ArrDelayMinutes)=-0.0053316629599336335)]
# Flight_Number_Reporting_Airline [Row(corr(Flight_Number_Reporting_Airline, ArrDelayMinutes)=0.024421422150174486)]
# OriginAirportID [Row(corr(OriginAirportID, ArrDelayMinutes)=-0.003533904269413558)]
# OriginAirportSeqID [Row(corr(OriginAirportSeqID, ArrDelayMinutes)=-0.0035339014500098092)]
# OriginCityMarketID [Row(corr(OriginCityMarketID, ArrDelayMinutes)=-0.005711262350132093)]
# Origin [Row(corr(Origin, ArrDelayMinutes)=None)]
# OriginCityName [Row(corr(OriginCityName, ArrDelayMinutes)=None)]
# OriginState [Row(corr(OriginState, ArrDelayMinutes)=None)]
# OriginStateFips [Row(corr(OriginStateFips, ArrDelayMinutes)=0.006260395916424323)]
# OriginStateName [Row(corr(OriginStateName, ArrDelayMinutes)=None)]
# OriginWac [Row(corr(OriginWac, ArrDelayMinutes)=-0.013763183804067282)]
# DestAirportID [Row(corr(DestAirportID, ArrDelayMinutes)=0.0013469010530569525)]
# DestAirportSeqID [Row(corr(DestAirportSeqID, ArrDelayMinutes)=0.00134692770889401)]
# DestCityMarketID [Row(corr(DestCityMarketID, ArrDelayMinutes)=-0.002521937265404725)]
# Dest [Row(corr(Dest, ArrDelayMinutes)=None)]
# DestCityName [Row(corr(DestCityName, ArrDelayMinutes)=None)]
# DestState [Row(corr(DestState, ArrDelayMinutes)=None)]
# DestStateFips [Row(corr(DestStateFips, ArrDelayMinutes)=0.003844719221450387)]
# DestStateName [Row(corr(DestStateName, ArrDelayMinutes)=None)]
# DestWac [Row(corr(DestWac, ArrDelayMinutes)=-0.014263065888579304)]
# CRSDepTime [Row(corr(CRSDepTime, ArrDelayMinutes)=0.09002345346802962)]
# DepTime [Row(corr(DepTime, ArrDelayMinutes)=0.1354334778775246)]
# DepDelay [Row(corr(DepDelay, ArrDelayMinutes)=0.9671386391356969)]
# DepDelayMinutes [Row(corr(DepDelayMinutes, ArrDelayMinutes)=0.9717372148621114)]
# DepDel15 [Row(corr(DepDel15, ArrDelayMinutes)=0.5494798364092823)]
# DepartureDelayGroups [Row(corr(DepartureDelayGroups, ArrDelayMinutes)=0.8389429851885519)]
# DepTimeBlk [Row(corr(DepTimeBlk, ArrDelayMinutes)=None)]
# TaxiOut [Row(corr(TaxiOut, ArrDelayMinutes)=0.18787469155259945)]
# WheelsOff [Row(corr(WheelsOff, ArrDelayMinutes)=0.1302555080781829)]
# WheelsOn [Row(corr(WheelsOn, ArrDelayMinutes)=0.04069769929550899)]
# TaxiIn [Row(corr(TaxiIn, ArrDelayMinutes)=0.08635248739483996)]
# CRSArrTime [Row(corr(CRSArrTime, ArrDelayMinutes)=0.08196378162629478)]
# ArrTime [Row(corr(ArrTime, ArrDelayMinutes)=0.03305757238508418)]
# ArrDelay [Row(corr(ArrDelay, ArrDelayMinutes)=0.9795697757620128)]
# ArrDelayMinutes [Row(corr(ArrDelayMinutes, ArrDelayMinutes)=1.0)]
# ArrDel15 [Row(corr(ArrDel15, ArrDelayMinutes)=0.5945446989553815)]
# ArrivalDelayGroups [Row(corr(ArrivalDelayGroups, ArrDelayMinutes)=0.856485514985197)]
# ArrTimeBlk [Row(corr(ArrTimeBlk, ArrDelayMinutes)=None)]
# Cancelled [Row(corr(Cancelled, ArrDelayMinutes)=None)]
# CancellationCode [Row(corr(CancellationCode, ArrDelayMinutes)=None)]
# Diverted [Row(corr(Diverted, ArrDelayMinutes)=None)]
# CRSElapsedTime [Row(corr(CRSElapsedTime, ArrDelayMinutes)=0.00805463813856499)]
# ActualElapsedTime [Row(corr(ActualElapsedTime, ArrDelayMinutes)=0.0456293701243955)]
# AirTime [Row(corr(AirTime, ArrDelayMinutes)=0.016081861670258102)]
# Flights [Row(corr(Flights, ArrDelayMinutes)=None)]
# Distance [Row(corr(Distance, ArrDelayMinutes)=0.003607854539498023)]
# DistanceGroup [Row(corr(DistanceGroup, ArrDelayMinutes)=0.003224469405336706)]
# CarrierDelay [Row(corr(CarrierDelay, ArrDelayMinutes)=0.6300815734304939)]
# WeatherDelay [Row(corr(WeatherDelay, ArrDelayMinutes)=0.2828489765365706)]
# NASDelay [Row(corr(NASDelay, ArrDelayMinutes)=0.27429322600244266)]
# SecurityDelay [Row(corr(SecurityDelay, ArrDelayMinutes)=0.019028943371727308)]
# LateAircraftDelay [Row(corr(LateAircraftDelay, ArrDelayMinutes)=0.49888515718335746)]
# FirstDepTime [Row(corr(FirstDepTime, ArrDelayMinutes)=0.07415254251966975)]
# TotalAddGTime [Row(corr(TotalAddGTime, ArrDelayMinutes)=0.4091312443442107)]
# LongestAddGTime [Row(corr(LongestAddGTime, ArrDelayMinutes)=0.39674863545087546)]
# DivAirportLandings [Row(corr(DivAirportLandings, ArrDelayMinutes)=None)]
# DivReachedDest [Row(corr(DivReachedDest, ArrDelayMinutes)=None)]
# DivActualElapsedTime [Row(corr(DivActualElapsedTime, ArrDelayMinutes)=None)]
# DivArrDelay [Row(corr(DivArrDelay, ArrDelayMinutes)=None)]
# DivDistance [Row(corr(DivDistance, ArrDelayMinutes)=None)]
# Div1Airport [Row(corr(Div1Airport, ArrDelayMinutes)=None)]
# Div1AirportID [Row(corr(Div1AirportID, ArrDelayMinutes)=None)]
# Div1AirportSeqID [Row(corr(Div1AirportSeqID, ArrDelayMinutes)=None)]
# Div1WheelsOn [Row(corr(Div1WheelsOn, ArrDelayMinutes)=None)]
# Div1TotalGTime [Row(corr(Div1TotalGTime, ArrDelayMinutes)=None)]
# Div1LongestGTime [Row(corr(Div1LongestGTime, ArrDelayMinutes)=None)]
# Div1WheelsOff [Row(corr(Div1WheelsOff, ArrDelayMinutes)=None)]
# Div1TailNum [Row(corr(Div1TailNum, ArrDelayMinutes)=None)]
# Div2Airport [Row(corr(Div2Airport, ArrDelayMinutes)=None)]
# Div2AirportID [Row(corr(Div2AirportID, ArrDelayMinutes)=0.173113584718758)]
# Div2AirportSeqID [Row(corr(Div2AirportSeqID, ArrDelayMinutes)=0.17310978789090614)]
# Div2WheelsOn [Row(corr(Div2WheelsOn, ArrDelayMinutes)=None)]
# Div2TotalGTime [Row(corr(Div2TotalGTime, ArrDelayMinutes)=None)]
# Div2LongestGTime [Row(corr(Div2LongestGTime, ArrDelayMinutes)=None)]
# Div2WheelsOff [Row(corr(Div2WheelsOff, ArrDelayMinutes)=None)]
# Div2TailNum [Row(corr(Div2TailNum, ArrDelayMinutes)=None)]
# Div3Airport [Row(corr(Div3Airport, ArrDelayMinutes)=None)]
# Div3AirportID [Row(corr(Div3AirportID, ArrDelayMinutes)=None)]
# Div3AirportSeqID [Row(corr(Div3AirportSeqID, ArrDelayMinutes)=None)]
# Div3WheelsOn [Row(corr(Div3WheelsOn, ArrDelayMinutes)=None)]
# Div3TotalGTime [Row(corr(Div3TotalGTime, ArrDelayMinutes)=None)]
# Div3LongestGTime [Row(corr(Div3LongestGTime, ArrDelayMinutes)=None)]
# Div3WheelsOff [Row(corr(Div3WheelsOff, ArrDelayMinutes)=None)]
# Div3TailNum [Row(corr(Div3TailNum, ArrDelayMinutes)=None)]
# Div4Airport [Row(corr(Div4Airport, ArrDelayMinutes)=None)]
# Div4AirportID [Row(corr(Div4AirportID, ArrDelayMinutes)=None)]
# Div4AirportSeqID [Row(corr(Div4AirportSeqID, ArrDelayMinutes)=None)]
# Div4WheelsOn [Row(corr(Div4WheelsOn, ArrDelayMinutes)=None)]
# Div4TotalGTime [Row(corr(Div4TotalGTime, ArrDelayMinutes)=None)]
# Div4LongestGTime [Row(corr(Div4LongestGTime, ArrDelayMinutes)=None)]
# Div4WheelsOff [Row(corr(Div4WheelsOff, ArrDelayMinutes)=None)]
# Div4TailNum [Row(corr(Div4TailNum, ArrDelayMinutes)=None)]
# Div5Airport [Row(corr(Div5Airport, ArrDelayMinutes)=None)]
# Div5AirportID [Row(corr(Div5AirportID, ArrDelayMinutes)=None)]
# Div5AirportSeqID [Row(corr(Div5AirportSeqID, ArrDelayMinutes)=None)]
# Div5WheelsOn [Row(corr(Div5WheelsOn, ArrDelayMinutes)=None)]
# Div5TotalGTime [Row(corr(Div5TotalGTime, ArrDelayMinutes)=None)]
# Div5LongestGTime [Row(corr(Div5LongestGTime, ArrDelayMinutes)=None)]
# Div5WheelsOff [Row(corr(Div5WheelsOff, ArrDelayMinutes)=None)]
# Div5TailNum [Row(corr(Div5TailNum, ArrDelayMinutes)=None)]
# _c109 [Row(corr(_c109, ArrDelayMinutes)=None)]
# </div>

# %%
raw_data = df.na.drop(subset=["Tail_Number"]) \
              .filter("WeatherDelay>0") \
              .select(
                'Month', 
                'DayOfWeek',
                'Origin', 
                'Dest', 
                'DepDelay',
                'WeatherDelay',
                'ArrDelayMinutes',
                'AirTime',
                'Distance'
            )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
string_columns = ['Origin', 'Dest']
indexed_columns = ['Origin_cat', 'Dest_cat']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
indexer = StringIndexer(inputCols=string_columns, outputCols=indexed_columns)
indexed_data = indexer.fit(raw_data).transform(raw_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
indexed_data.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [&#39;Month&#39;,
#  &#39;DayOfWeek&#39;,
#  &#39;Origin&#39;,
#  &#39;Dest&#39;,
#  &#39;DepDelay&#39;,
#  &#39;WeatherDelay&#39;,
#  &#39;ArrDelayMinutes&#39;,
#  &#39;AirTime&#39;,
#  &#39;Distance&#39;,
#  &#39;Origin_cat&#39;,
#  &#39;Dest_cat&#39;]</div>

# %%
assembler = VectorAssembler(
    inputCols=['Month', 'DayOfWeek', 'WeatherDelay', 'DepDelay', 'Origin_cat', 'Dest_cat', 'AirTime', 'Distance'],
    outputCol='features'
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output_data = assembler.transform(indexed_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_data = output_data.select(['features', 'ArrDelayMinutes'])
final_data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+---------------+
#             features|ArrDelayMinutes|
# +--------------------+---------------+
# [1.0,3.0,9.0,10.0...|           19.0|
# [1.0,3.0,12.0,16....|           28.0|
# [1.0,3.0,11.0,14....|           25.0|
# [1.0,3.0,6.0,13.0...|           19.0|
# [2.0,3.0,28.0,28....|           76.0|
# [2.0,1.0,2.0,154....|          162.0|
# [2.0,5.0,12.0,28....|           29.0|
# [2.0,5.0,35.0,35....|           48.0|
# [2.0,2.0,19.0,108...|          113.0|
# [2.0,2.0,14.0,94....|          143.0|
# [2.0,5.0,16.0,16....|           40.0|
# [2.0,5.0,33.0,44....|           36.0|
# [2.0,3.0,26.0,81....|          115.0|
# [2.0,1.0,7.0,22.0...|           21.0|
# [2.0,3.0,261.0,26...|          271.0|
# [2.0,5.0,58.0,76....|          151.0|
# [2.0,5.0,3.0,161....|          184.0|
# [2.0,5.0,5.0,5.0,...|           16.0|
# [2.0,5.0,99.0,104...|           99.0|
# [2.0,5.0,29.0,94....|          128.0|
# +--------------------+---------------+
# only showing top 20 rows
#
# </div>

# %%
train_data, test_data = final_data.randomSplit([0.8, 0.2])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lr = LinearRegression(labelCol='ArrDelayMinutes', maxIter=1000, tol=1e-05, regParam=0.3, elasticNetParam=0.8)
weatherDelayModel = lr.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print("Coefficients: {} Intercept: {}".format(weatherDelayModel.coefficients,weatherDelayModel.intercept))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Coefficients: [-0.05119996364608083,0.0,0.060809127328238524,0.928060780493694,-0.005248113918070031,0.0,0.3883429546002871,-0.047626950875283444] Intercept: 5.085130489498985
# </div>

# %%
weatherDelayModel_results = weatherDelayModel.evaluate(test_data)
print(f'RSquared Error {weatherDelayModel_results.r2}\nAccuracy {weatherDelayModel_results.r2:.2%}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RSquared Error 0.952493560905543
# Accuracy 95.25%
# </div>
